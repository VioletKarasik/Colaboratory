# %% [markdown]
# <a href="https://colab.research.google.com/github/VioletKarasik/Colaboratory/blob/main/lesson2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Импорт библиотек

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ###Конфигурация Seaborn

# %%
sns.set()
# %config InlineBackend.figure_format = 'retina'

# %% [markdown]
# ###Открытие датасета

# %%
df = pd.read_excel("ADHD.xlsx")

# %% [markdown]
# ###Базовая информация о таблице

# %%
df.head()
# Out:
#    age     sex specify      home_language  \
# 0   22  female     NaN           xitsonga
# 1   21    male     NaN            english
# 2   19  female     NaN            isizulu
# 3   20    male     NaN  afrikaans/english
# 4   20  female     NaN           isixhosa
#
#   have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                 no
# 1                                                 no
# 2                                                yes
# 3                                                yes
# 4                                                 no
#
#   if_yes_please_list_these_difficulties_and_or_symptoms  \
# 0                                                 na
# 1                                               none
# 2        mental breakdowns.  anxiety.  panic attacks
# 3            depression and anxiety, as well as adhd
# ...

# %%
print(df.shape) #вывод размерности матрицы датасета
# Out:
# (506, 110)

# %%
print("Типы колонок:")
print(df.dtypes)
# Out:
# Типы колонок:
# age                                                                                                                                int64
# sex                                                                                                                               object
# specify                                                                                                                           object
# home_language                                                                                                                     object
# have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school     object
#                                                                                                                                   ...
# bai1_item_20                                                                                                                       int64
# ...

# %%
print("Список колонок:")
print(df.columns) #вывод в виде списка названия колонок
# Out:
# Список колонок:
# Index(['age', 'sex', 'specify', 'home_language',
#        'have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school',
#        'if_yes_please_list_these_difficulties_and_or_symptoms',
#        'if_you_have_ever_experienced_difficulties_and_or_symptoms_of_a_mental_illness_how_old_were_you_when_this_started',
#        'have_you_ever_been_diagnosed_with_a_mental_illness',
#        'if_you_have_been_diagnosed_formally_or_informally_please_list_the_diagnosis_diagnoses',
#        'was_this_diagnosis_made_before_or_after_you_left_high_school',
#        ...
#        'bai1_item_15', 'bai1_item_16', 'bai1_item_17', 'bai1_item_18',
#        'bai1_item_19', 'bai1_item_20', 'bai1_item_21', 'bai1_total',
#        'asrs1_total.y', 'aas_change'],
#       dtype='object', length=110)

# %%
print(df.info)
# Out:
# <bound method DataFrame.info of      age     sex specify      home_language  \
# 0     22  female     NaN           xitsonga
# 1     21    male     NaN            english
# 2     19  female     NaN            isizulu
# 3     20    male     NaN  afrikaans/english
# 4     20  female     NaN           isixhosa
# ..   ...     ...     ...                ...
# 501   18  female     NaN            english
# 502   18  female     NaN           isixhosa
# 503   18  female     NaN            english
# 504   18  female     NaN            english
# 505   18  female     NaN            english
#
#     have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                   no
# 1                                                   no
# 2                                                  yes
# 3                                                  yes
# ...

# %%
print(df.describe())
# Out:
#               age  bdi1_item_1  bdi1_item_2  bdi1_item_3  bdi1_item_4  \
# count  506.000000   506.000000   506.000000   506.000000   506.000000
# mean    18.428854     0.517787     0.478261     0.452569     0.849802
# std      0.720202     0.803877     0.752897     0.775059     0.865837
# min     18.000000     0.000000     0.000000     0.000000     0.000000
# 25%     18.000000     0.000000     0.000000     0.000000     0.000000
# 50%     18.000000     0.000000     0.000000     0.000000     1.000000
# 75%     19.000000     1.000000     1.000000     1.000000     1.000000
# max     22.000000     3.000000     3.000000     3.000000     3.000000
#
#        bdi1_item_5  bdi1_item_6  bdi1_item_7  bdi1_item_8  bdi1_item_9  ...  \
# count   506.000000   506.000000   506.000000   506.000000   506.000000  ...
# mean      0.719368     0.454545     0.474308     0.992095     0.349802  ...
# std       0.837429     0.884917     0.778633     0.927008     0.627876  ...
# ...

# %%
print(df.describe(exclude=['object','bool'] ))
# Out:
#               age  bdi1_item_1  bdi1_item_2  bdi1_item_3  bdi1_item_4  \
# count  506.000000   506.000000   506.000000   506.000000   506.000000
# mean    18.428854     0.517787     0.478261     0.452569     0.849802
# std      0.720202     0.803877     0.752897     0.775059     0.865837
# min     18.000000     0.000000     0.000000     0.000000     0.000000
# 25%     18.000000     0.000000     0.000000     0.000000     0.000000
# 50%     18.000000     0.000000     0.000000     0.000000     1.000000
# 75%     19.000000     1.000000     1.000000     1.000000     1.000000
# max     22.000000     3.000000     3.000000     3.000000     3.000000
#
#        bdi1_item_5  bdi1_item_6  bdi1_item_7  bdi1_item_8  bdi1_item_9  ...  \
# count   506.000000   506.000000   506.000000   506.000000   506.000000  ...
# mean      0.719368     0.454545     0.474308     0.992095     0.349802  ...
# std       0.837429     0.884917     0.778633     0.927008     0.627876  ...
# ...

# %%
print(df.describe(include=['object','bool'] ))
# Out:
#            sex     specify home_language  \
# count      506          11           506
# unique       3           4            24
# top     female  non-binary       english
# freq       412           7           298
#
#        have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# count                                                 506
# unique                                                  2
# top                                                   yes
# freq                                                  327
#
#        if_yes_please_list_these_difficulties_and_or_symptoms  \
# count                                                 425
# unique                                                292
# top                                               anxiety
# freq                                                   34
#
# ...

# %%
df['home_language'].value_counts()
# Out:
# english                      298
# isixhosa                      77
# isizulu                       37
# afrikaans                     28
# setswana                      15
# sesotho                       14
# sepedi                        12
# xitsonga                       3
# english/afrikaans              3
# english/isixhosa               3
# tshivenda                      3
# english/setswana               1
# sesotho/english                1
# english/swahili                1
# isizulu/setswana               1
# hindi                          1
# setswana/xitsonga              1
# shona                          1
# mandarin                       1
# gujarati                       1
# siswati                        1
# german                         1
# afrikaans/english              1
# afrikaans/sesotho/english      1
# Name: home_language, dtype: int64

# %%
df['sex'].value_counts()
# Out:
# female    412
# male       83
# other      11
# Name: sex, dtype: int64

# %% [markdown]
# ###Распределение по столбцу

# %%
df['age'].value_counts(normalize=True)
# Out:
# 18    0.671937
# 19    0.254941
# 20    0.053360
# 21    0.011858
# 22    0.007905
# Name: age, dtype: float64

# %% [markdown]
# ###Сортировка по признаку

# %%
df.sort_values(by=['bdi1_item_2'], ascending=True)
# Out:
#      age     sex specify home_language  \
# 0     22  female     NaN      xitsonga
# 307   19  female     NaN       english
# 306   18    male     NaN       english
# 305   18  female     NaN       english
# 302   18    male     NaN       english
# ..   ...     ...     ...           ...
# 448   19    male     NaN       english
# 48    19  female     NaN       english
# 429   18  female     NaN      isixhosa
# 93    18  female     NaN        sepedi
# 505   18  female     NaN       english
#
#     have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                   no
# 307                                                yes
# 306                                                yes
# 305                                                yes
# 302                                                 no
# ..                                                 ...
# ...

# %%
df.sort_values(by=['bdi1_item_3','bdi1_item_4'], ascending=False).head()
# Out:
#      age     sex     specify home_language  \
# 18    19    male         NaN       isizulu
# 61    19  female         NaN       english
# 280   18   other  non-binary       english
# 128   18  female         NaN       english
# 160   18  female         NaN       english
#
#     have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 18                                                 yes
# 61                                                 yes
# 280                                                yes
# 128                                                yes
# 160                                                 no
#
#     if_yes_please_list_these_difficulties_and_or_symptoms  \
# 18               depression, anxiety, bipolar disorder
# 61   self harm, depression, anxiety, severe mood sw...
# 280  anxiety, depression (i don't know if my autism...
# 128  anxiety, depression, insomnia, panic and anxie...
# ...

# %%
df['bdi1_item_4'].mean()
# Out:
# 0.849802371541502

# %%
print(1- df['bdi1_item_4'].mean()) #отток пользователей
# Out:
# 0.15019762845849804

# %%
df[df["bdi1_item_4"] == 1] #нелояльные пользователи
# Out:
#      age     sex specify home_language  \
# 0     22  female     NaN      xitsonga
# 2     19  female     NaN       isizulu
# 4     20  female     NaN      isixhosa
# 6     21  female     NaN      isixhosa
# 8     19  female     NaN       english
# ..   ...     ...     ...           ...
# 489   18  female     NaN       english
# 492   18  female     NaN       isizulu
# 495   18  female     NaN       english
# 497   18  female     NaN       english
# 501   18  female     NaN       english
#
#     have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                   no
# 2                                                  yes
# 4                                                   no
# 6                                                   no
# 8                                                  yes
# ..                                                 ...
# ...

# %%
df[df["bdi1_item_4"] == 1].mean()
# Out:
# <ipython-input-32-25318c97301e>:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df[df["bdi1_item_4"] == 1].mean()
# age              18.387560
# bdi1_item_1       0.526316
# bdi1_item_2       0.507177
# bdi1_item_3       0.497608
# bdi1_item_4       1.000000
#                    ...
# bai1_item_20      0.588517
# bai1_item_21      0.913876
# bai1_total       23.339713
# asrs1_total.y    23.454545
# aas_change        0.060177
# Length: 94, dtype: float64

# %%
df[df["bdi1_item_4"] == 1]["age"].mean()
# Out:
# 18.38755980861244

# %% [markdown]
# ###Индексация

# %%
df.loc[0:10]
# Out:
#     age     sex specify      home_language  \
# 0    22  female     NaN           xitsonga
# 1    21    male     NaN            english
# 2    19  female     NaN            isizulu
# 3    20    male     NaN  afrikaans/english
# 4    20  female     NaN           isixhosa
# 5    20    male     NaN            english
# 6    21  female     NaN           isixhosa
# 7    19  female     NaN           setswana
# 8    19  female     NaN            english
# 9    20  female     NaN            english
# 10   19  female     NaN            english
#
#    have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                  no
# 1                                                  no
# 2                                                 yes
# 3                                                 yes
# 4                                                  no
# ...

# %%
df.loc[0:10,'have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school']
# Out:
# 0      no
# 1      no
# 2     yes
# 3     yes
# 4      no
# 5      no
# 6      no
# 7     yes
# 8     yes
# 9     yes
# 10    yes
# Name: have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school, dtype: object

# %%
df.iloc[0:10,1:5]
# Out:
#       sex specify      home_language  \
# 0  female     NaN           xitsonga
# 1    male     NaN            english
# 2  female     NaN            isizulu
# 3    male     NaN  afrikaans/english
# 4  female     NaN           isixhosa
# 5    male     NaN            english
# 6  female     NaN           isixhosa
# 7  female     NaN           setswana
# 8  female     NaN            english
# 9  female     NaN            english
#
#   have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school
# 0                                                 no
# 1                                                 no
# 2                                                yes
# 3                                                yes
# 4                                                 no
# 5                                                 no
# 6                                                 no
# ...

# %%
df[:1] #первая строчка
# Out:
#    age     sex specify home_language  \
# 0   22  female     NaN      xitsonga
#
#   have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                 no
#
#   if_yes_please_list_these_difficulties_and_or_symptoms  \
# 0                                                 na
#
#   if_you_have_ever_experienced_difficulties_and_or_symptoms_of_a_mental_illness_how_old_were_you_when_this_started  \
# 0                                                 na
#
#   have_you_ever_been_diagnosed_with_a_mental_illness  \
# 0                                                 no
#
#   if_you_have_been_diagnosed_formally_or_informally_please_list_the_diagnosis_diagnoses  \
# 0                                                 na
#
#   was_this_diagnosis_made_before_or_after_you_left_high_school  ...  \
# 0                                     not applicable            ...
#
# ...

# %%
df[-1:] #последняя строчка
# Out:
#      age     sex specify home_language  \
# 505   18  female     NaN       english
#
#     have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 505                                                yes
#
#     if_yes_please_list_these_difficulties_and_or_symptoms  \
# 505                                            anxiety
#
#     if_you_have_ever_experienced_difficulties_and_or_symptoms_of_a_mental_illness_how_old_were_you_when_this_started  \
# 505  yes, i actually think it started when i was in...
#
#     have_you_ever_been_diagnosed_with_a_mental_illness  \
# 505                                                 no
#
#     if_you_have_been_diagnosed_formally_or_informally_please_list_the_diagnosis_diagnoses  \
# 505                                                NaN
#
#     was_this_diagnosis_made_before_or_after_you_left_high_school  ...  \
# ...

# %% [markdown]
# ###Применение функций к ячейкам

# %%
df2 = df

# %%
df2.head()
# Out:
#    age     sex specify      home_language  \
# 0   22  female     NaN           xitsonga
# 1   21    male     NaN            english
# 2   19  female     NaN            isizulu
# 3   20    male     NaN  afrikaans/english
# 4   20  female     NaN           isixhosa
#
#   have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                 no
# 1                                                 no
# 2                                                yes
# 3                                                yes
# 4                                                 no
#
#   if_yes_please_list_these_difficulties_and_or_symptoms  \
# 0                                                 na
# 1                                               none
# 2        mental breakdowns.  anxiety.  panic attacks
# 3            depression and anxiety, as well as adhd
# ...

# %% [markdown]
# ###Сводные таблицы

# %%
pd.crosstab(df['bdi1_item_2'], df['bdi1_item_4'],  normalize=True)
# Out:
# bdi1_item_4         0         1         2         3
# bdi1_item_2
# 0            0.339921  0.237154  0.049407  0.021739
# 1            0.049407  0.146245  0.045455  0.015810
# 2            0.001976  0.025692  0.017787  0.017787
# 3            0.007905  0.003953  0.013834  0.005929

# %%
(df.pivot_table(['age', 'bdi1_item_1'], ['bdi1_item_2'], aggfunc='mean').head(5)).sort_values(by=['bdi1_item_1', 'bdi1_item_1'], ascending=[False,False])
# Out:
#                    age  bdi1_item_1
# bdi1_item_2
# 3            18.625000     1.687500
# 2            18.281250     1.000000
# 1            18.323077     0.661538
# 0            18.475610     0.356707

# %% [markdown]
# ###Преобразование датафреймов

# %%
df3 = df

# %%
total_calls = df['bdi1_item_4'] + df['bdi1_item_5'] + df['bdi1_item_6']
df3.insert(loc=len(df3.columns), column="Total calls", value=total_calls)
df3
# Out:
#      age     sex specify      home_language  \
# 0     22  female     NaN           xitsonga
# 1     21    male     NaN            english
# 2     19  female     NaN            isizulu
# 3     20    male     NaN  afrikaans/english
# 4     20  female     NaN           isixhosa
# ..   ...     ...     ...                ...
# 501   18  female     NaN            english
# 502   18  female     NaN           isixhosa
# 503   18  female     NaN            english
# 504   18  female     NaN            english
# 505   18  female     NaN            english
#
#     have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                   no
# 1                                                   no
# 2                                                  yes
# 3                                                  yes
# 4                                                   no
# ...

# %% [markdown]
# ###Визуализация

# %%
pd.crosstab(df['age'], df['bdi1_item_2'], margins=True)
# Out:
# bdi1_item_2    0    1   2   3  All
# age
# 18           213   95  23   9  340
# 19            84   31   9   5  129
# 20            24    2   0   1   27
# 21             4    1   0   1    6
# 22             3    1   0   0    4
# All          328  130  32  16  506

# %%
tmp = pd.crosstab(df['age'], df['bdi1_item_1'])

# %%
sns.countplot(data=tmp)
# Out:
# <Axes: xlabel='bdi1_item_1', ylabel='count'>

# %%
sns.countplot(x="age", hue="bdi1_item_1", data=df)
# Out:
# <Axes: xlabel='age', ylabel='count'>

# %%
sns.countplot(x="bdi1_item_2", hue="bdi1_item_3", data=df)
# Out:
# <Axes: xlabel='bdi1_item_2', ylabel='count'>
