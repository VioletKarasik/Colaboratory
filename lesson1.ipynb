# %% [markdown]
# <a href="https://colab.research.google.com/github/VioletKarasik/Colaboratory/blob/main/lesson1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
testik = pd.read_excel("ADHD.xlsx")

count_rows = testik.shape[0]
count_columns = testik.shape[1]
print("Количество строк в дата сета: ", count_rows, "\n Количество столбцов в дата сете: ", count_columns)

print("Начало: ", testik.head(), "\n Конец: ", testik.tail())

print("Колонки ", testik.columns)

print("Среднее-арифметическое по колонкам:", testik.mean(numeric_only = True))

print("Минимум: ", testik.min(numeric_only = True), "\n Максисмум: ", testik.max(numeric_only = True))
# Out:
# Количество строк в дата сета:  506
#  Количество столбцов в дата сете:  110
# Начало:     age     sex specify      home_language  \
# 0   22  female     NaN           xitsonga
# 1   21    male     NaN            english
# 2   19  female     NaN            isizulu
# 3   20    male     NaN  afrikaans/english
# 4   20  female     NaN           isixhosa
#
#   have_you_ever_experienced_any_mental_health_difficulties_or_symptoms_before_starting_university_e_g_in_primary_or_high_school  \
# 0                                                 no
# 1                                                 no
# 2                                                yes
# 3                                                yes
# 4                                                 no
#
#   if_yes_please_list_these_difficulties_and_or_symptoms  \
# 0                                                 na
# 1                                               none
# 2        mental breakdowns.  anxiety.  panic attacks
# ...
